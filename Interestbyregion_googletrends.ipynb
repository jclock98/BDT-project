# %%
# !pip install pytrends
# Out:
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=b09fe3cd71becfadd82c8f27a270538d802a4e0979d00c2a262e46f0caa92fa2
#   Stored in directory: /Users/jacopoclocchiatti/Library/Caches/pip/wheels/e8/78/c8/18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# ...

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='it-IT', geo='IT')
kw_list = ["McFit Milano"]
pytrends.build_payload(kw_list,timeframe = 'now 1-d' )
df = pytrends.interest_by_region(resolution='Italy', inc_low_vol=True, inc_geo_code=False)
df.sort_values(by=kw_list,ascending=False)
# Out:
#                        McFit Milano
# geoName
# Lombardia                       100
# Piemonte                         50
# Abruzzo                           0
# Valle d'Aosta                     0
# Umbria                            0
# Trentino-Alto Adige               0
# Toscana                           0
# Sicilia                           0
# Sardegna                          0
# Puglia                            0
# Molise                            0
# Basilicata                        0
# Marche                            0
# Liguria                           0
# Lazio                             0
# Friuli-Venezia Giulia             0
# Emilia-Romagna                    0
# Campania                          0
# Calabria                          0
# Veneto                            0

# %%
df
# Out:
#                        sport
# geoName
# Abruzzo                   72
# Basilicata                60
# Calabria                  63
# Campania                  64
# Emilia-Romagna            70
# Friuli-Venezia Giulia     45
# Lazio                    100
# Liguria                   60
# Lombardia                 72
# Marche                    77
# Molise                    66
# Piemonte                  56
# Puglia                    57
# Sardegna                  63
# Sicilia                   57
# Toscana                   68
# Trentino-Alto Adige       52
# Umbria                    65
# Valle d'Aosta             68
# Veneto                    66

# %%
# Out:
#                        sport
# geoName
# Lazio                    100
# Marche                    77
# Abruzzo                   72
# Lombardia                 72
# Emilia-Romagna            70
# Valle d'Aosta             68
# Toscana                   68
# Molise                    66
# Veneto                    66
# Umbria                    65
# Campania                  64
# Sardegna                  63
# Calabria                  62
# Liguria                   60
# Basilicata                60
# Puglia                    57
# Sicilia                   57
# Piemonte                  56
# Trentino-Alto Adige       53
# Friuli-Venezia Giulia     46
